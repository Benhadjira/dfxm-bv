# %% [markdown]
# # Compare data-driven and crystallographic-constrained models
#
# Load benchmark artifacts and compare the two trained models with training curves, noise robustness, benchmark metrics, and summary plots. Run `notebooks/01_training/crystallographic_resnet_models.ipynb` first if artifacts do not exist.

# %%
from bv_repro.visualization import load_benchmark_artifacts, plot_all, print_model_metrics_latex

# %%
results, summary, metrics = load_benchmark_artifacts("benchmark_artifacts")
plot_all(results, summary, metrics)

# LaTeX table for the manuscript
print_model_metrics_latex(metrics)
