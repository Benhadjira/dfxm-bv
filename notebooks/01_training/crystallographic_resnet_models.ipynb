# %% [markdown]
# # Crystallographic and Data-Driven Model Benchmark
#
# This notebook is intentionally thin. The reusable model, training, benchmark, and uncertainty code lives in `crystallographic_benchmark.py`.

# %%
from bv_repro.training import BenchmarkConfig, run_benchmark

# %%
config = BenchmarkConfig()
result = run_benchmark(config)
